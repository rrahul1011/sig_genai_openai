# %%
import numpy as np  
import pandas as pd

# %%
df = pd.read_csv("Retail_Data.csv")

# %%
df
# Out:
#         Unnamed: 0        geo  channel     brand    SKU       month  year  \
# 0                0  Australia  Offline   Brand_2  SKU_1  2017-01-01  2017
# 1                1  Australia  Offline   Brand_2  SKU_1  2017-02-01  2017
# 2                2  Australia  Offline   Brand_2  SKU_1  2017-03-01  2017
# 3                3  Australia  Offline   Brand_2  SKU_1  2017-04-01  2017
# 4                4  Australia  Offline   Brand_2  SKU_1  2017-05-01  2017
# ...            ...        ...      ...       ...    ...         ...   ...
# 319693      527254    Uruguay   Online  Brand_21  SKU_1  2026-02-01  2026
# 319694      527257    Uruguay   Online  Brand_21  SKU_1  2026-03-01  2026
# 319695      527260    Uruguay   Online  Brand_21  SKU_1  2026-04-01  2026
# 319696      527263    Uruguay   Online  Brand_21  SKU_1  2026-05-01  2026
# 319697      527266    Uruguay   Online  Brand_21  SKU_1  2026-06-01  2026
#
#           scenario     volume    Region Name Market Name    Category
# ...

# %%
import streamlit as st
def sum(a,b):
    return a+b
sum(5,3)
st.write(sum(5,3))
# Out:
# 2023-09-02 18:58:29.430
# ...
#   command:
#
#     streamlit run /Users/rahulkushwaha/anaconda3/envs/genai/lib/python3.11/site-packages/ipykernel_launcher.py [ARGUMENTS]
